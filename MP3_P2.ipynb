# %%
# In a terminal, Run the `download_data.sh` script in the data folder of assignment 3 part 2

# %%
import os
import random

import cv2
import numpy as np

import torch
from torch.utils.data import DataLoader
from torchvision import models

from src.resnet_yolo import resnet50
from yolo_loss import YoloLoss
from src.dataset import VocDetectorDataset
from src.eval_voc import evaluate
from src.predict import predict_image
from src.config import VOC_CLASSES, COLORS
from kaggle_submission import output_submission_csv

import matplotlib.pyplot as plt
import collections

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Initialization

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
# YOLO network hyperparameters
B = 2  # number of bounding box predictions per cell
S = 14  # width/height of network output grid (larger than 7x7 from paper since we use a different network)

# %% [markdown]
# To implement YOLO, we will rely on a pretrained classifier as the backbone for our detection network. In particular, we will use the ResNet50 architecture as a base for our detector. This is different from the base architecture in the Yolo paper and also results in a different output grid size (14x14 instead of 7x7).
#
# Models are typically pretrained on ImageNet since the dataset is very large (> 1 million images) and widely used. The pretrained model provides a very useful weight initialization for our detector, so that the network is able to learn quickly and effectively.

# %%
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 3521

# %%
load_network_path = 'checkpoints/best_detector.pth' 
pretrained = True

# use to load a previously trained network
if load_network_path is not None:
    print('Loading saved network from {}'.format(load_network_path))
    net = resnet50().to(device)
    net.load_state_dict(torch.load(load_network_path))
else:
    print('Load pre-trained model')
    net = resnet50(pretrained=pretrained).to(device)
# Out:
# Loading saved network from checkpoints/best_detector.pth

# %%
learning_rate = 0.001
num_epochs = 50
batch_size = 8 # 16, 24

# Yolo loss component coefficients (as given in Yolo v1 paper)
lambda_coord = 5
lambda_noobj = 0.5

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# Since Pascal is a small dataset (5000 in train+val) we have combined the train and val splits to train our detector.
#
# The train dataset loader also uses a variety of data augmentation techniques including random shift, scaling, crop, and flips. Data augmentation is slightly more complicated for detection datasets since the bounding box annotations must be kept consistent throughout the transformations.
#
# Since the output of the detector network we train is an SxSx(B*5+C), we use an encoder to convert the original bounding box coordinates into relative grid bounding box coordinates corresponding to the expected output. We also use a decoder which allows us to convert the opposite direction into image coordinate bounding boxes.

# %%
file_root_train = 'data/VOCdevkit_2007/VOC2007/JPEGImages/'
annotation_file_train = 'data/voc2007.txt'

train_dataset = VocDetectorDataset(root_img_dir=file_root_train,dataset_file=annotation_file_train,train=True, S=S)
train_loader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True,num_workers=2)
print('Loaded %d train images' % len(train_dataset))
# Out:
# Initializing dataset
# Loaded 5011 train images

# %%
file_root_test = 'data/VOCdevkit_2007/VOC2007test/JPEGImages/'
annotation_file_test = 'data/voc2007test.txt'

test_dataset = VocDetectorDataset(root_img_dir=file_root_test,dataset_file=annotation_file_test,train=False, S=S)
test_loader = DataLoader(test_dataset,batch_size=batch_size,shuffle=False,num_workers=2)
print('Loaded %d test images' % len(test_dataset))
# Out:
# Initializing dataset
# Loaded 4950 test images

# %%
data = train_dataset[0]

# %% [markdown]
# ## Set up training tools

# %%
criterion = YoloLoss(S, B, lambda_coord, lambda_noobj)
optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)

# %%
boxes = torch.tensor([[3,3,2,2]])
criterion.xywh2xyxy(boxes)
# Out:
# tensor([[0, 0, 1, 1]])

# %%
# (list) [(tensor) size (-1, 5)] [x, y, w, h, c]
pred_box_list = [torch.tensor([[5,5,3,3,0], [7,7,4,4,0]]), torch.tensor([[8,8,4,4,0], [3,3,2,2,0]])]
# (tensor)  size (-1, 4)
box_target = torch.tensor([[3,3,2,2], [8,8,4,4]])

best_ious, best_boxes = criterion.find_best_iou_boxes(pred_box_list, box_target)
print(best_ious)
print(best_boxes)
# Out:
# tensor([0.2500, 1.0000], device='cuda:0')
# tensor([[5., 5., 3., 3., 0.],
#         [7., 7., 4., 4., 0.]], device='cuda:0')

# %% [markdown]
# ## Train detector

# %%
best_test_loss = np.inf
learning_rate = 1e-3
for epoch in range(num_epochs):
    net.train()
    
    # Update learning rate late in training
    if epoch == 30 or epoch == 40:
        learning_rate /= 10.0

    for param_group in optimizer.param_groups:
        param_group['lr'] = learning_rate
    
    print('\n\nStarting epoch %d / %d' % (epoch + 1, num_epochs))
    print('Learning Rate for this epoch: {}'.format(learning_rate))
    
    total_loss = collections.defaultdict(int)
    
    for i, data in enumerate(train_loader):
        data = (item.to(device) for item in data)
        images, target_boxes, target_cls, has_object_map = data
        pred = net(images)
        loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
        for key in loss_dict:
            total_loss[key] += loss_dict[key].item()
        
        optimizer.zero_grad()
        loss_dict['total_loss'].backward()
        optimizer.step()
        
        if (i+1) % 50 == 0:
            outstring = 'Epoch [%d/%d], Iter [%d/%d], Loss: ' % ((epoch+1, num_epochs, i+1, len(train_loader)))
            outstring += ', '.join( "%s=%.3f" % (key[:-5], val / (i+1)) for key, val in total_loss.items() )
            print(outstring)
    
    # evaluate the network on the test data
    if (epoch + 1) % 5 == 0:
        test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
        print(epoch, test_aps)
    with torch.no_grad():
        test_loss = 0.0
        net.eval()
        for i, data in enumerate(test_loader):
            data = (item.to(device) for item in data)
            images, target_boxes, target_cls, has_object_map = data
            
            pred = net(images)
            loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
            test_loss += loss_dict['total_loss'].item()
        test_loss /= len(test_loader)
    
    if best_test_loss > test_loss:
        best_test_loss = test_loss
        print('Updating best test loss: %.5f' % best_test_loss)
        torch.save(net.state_dict(),'checkpoints/best_detector.pth')
    
    if (epoch+1) in [5, 10, 20, 30, 40]:
        torch.save(net.state_dict(),'checkpoints/detector_epoch_%d.pth' % (epoch+1))

    torch.save(net.state_dict(),'checkpoints/detector.pth')
# Out:
# Starting epoch 1 / 50
# Learning Rate for this epoch: 0.001
# Epoch [1/50], Iter [50/627], Loss: total=2.019, reg=7.697, containing_obj=5.105, no_obj=1.521, cls=1.825
# Epoch [1/50], Iter [100/627], Loss: total=2.017, reg=7.577, containing_obj=5.252, no_obj=1.494, cls=1.813
# Epoch [1/50], Iter [150/627], Loss: total=1.972, reg=7.450, containing_obj=5.058, no_obj=1.500, cls=1.768
# Epoch [1/50], Iter [200/627], Loss: total=1.978, reg=7.427, containing_obj=5.073, no_obj=1.507, cls=1.817
# Epoch [1/50], Iter [250/627], Loss: total=1.977, reg=7.427, containing_obj=5.050, no_obj=1.510, cls=1.828
# Epoch [1/50], Iter [300/627], Loss: total=1.968, reg=7.390, containing_obj=5.054, no_obj=1.493, cls=1.808
# Epoch [1/50], Iter [350/627], Loss: total=1.999, reg=7.563, containing_obj=5.082, no_obj=1.506, cls=1.845
# Epoch [1/50], Iter [400/627], Loss: total=2.012, reg=7.615, containing_obj=5.102, no_obj=1.533, cls=1.849
# Epoch [1/50], Iter [450/627], Loss: total=2.011, reg=7.645, containing_obj=5.091, no_obj=1.531, cls=1.825
# Epoch [1/50], Iter [500/627], Loss: total=2.020, reg=7.698, containing_obj=5.106, no_obj=1.525, cls=1.834
# Epoch [1/50], Iter [550/627], Loss: total=2.015, reg=7.672, containing_obj=5.105, no_obj=1.523, cls=1.823
# Epoch [1/50], Iter [600/627], Loss: total=2.021, reg=7.695, containing_obj=5.130, no_obj=1.517, cls=1.826
# Updating best test loss: 2.76959
#
#
# Starting epoch 2 / 50
# Learning Rate for this epoch: 0.001
# Epoch [2/50], Iter [50/627], Loss: total=2.034, reg=8.023, containing_obj=5.215, no_obj=1.388, cls=1.646
# Epoch [2/50], Iter [100/627], Loss: total=2.081, reg=8.310, containing_obj=5.271, no_obj=1.472, cls=1.597
# Epoch [2/50], Iter [150/627], Loss: total=2.053, reg=8.040, containing_obj=5.330, no_obj=1.495, cls=1.555
# Epoch [2/50], Iter [200/627], Loss: total=2.028, reg=7.886, containing_obj=5.219, no_obj=1.518, cls=1.604
# Epoch [2/50], Iter [250/627], Loss: total=2.044, reg=7.907, containing_obj=5.270, no_obj=1.537, cls=1.639
# Epoch [2/50], Iter [300/627], Loss: total=2.045, reg=7.898, containing_obj=5.231, no_obj=1.539, cls=1.690
# Epoch [2/50], Iter [350/627], Loss: total=2.054, reg=7.895, containing_obj=5.216, no_obj=1.534, cls=1.785
# Epoch [2/50], Iter [400/627], Loss: total=2.032, reg=7.774, containing_obj=5.175, no_obj=1.534, cls=1.770
# Epoch [2/50], Iter [450/627], Loss: total=2.034, reg=7.807, containing_obj=5.183, no_obj=1.524, cls=1.756
# Epoch [2/50], Iter [500/627], Loss: total=2.018, reg=7.735, containing_obj=5.119, no_obj=1.522, cls=1.768
# Epoch [2/50], Iter [550/627], Loss: total=2.014, reg=7.726, containing_obj=5.118, no_obj=1.509, cls=1.763
# Epoch [2/50], Iter [600/627], Loss: total=2.004, reg=7.661, containing_obj=5.107, no_obj=1.508, cls=1.756
#
#
# Starting epoch 3 / 50
# Learning Rate for this epoch: 0.001
# Epoch [3/50], Iter [50/627], Loss: total=2.068, reg=8.201, containing_obj=5.110, no_obj=1.494, cls=1.741
# Epoch [3/50], Iter [100/627], Loss: total=1.962, reg=7.767, containing_obj=4.878, no_obj=1.462, cls=1.588
# Epoch [3/50], Iter [150/627], Loss: total=2.008, reg=7.866, containing_obj=4.997, no_obj=1.490, cls=1.711
# Epoch [3/50], Iter [200/627], Loss: total=1.975, reg=7.663, containing_obj=4.918, no_obj=1.503, cls=1.718
# Epoch [3/50], Iter [250/627], Loss: total=1.951, reg=7.551, containing_obj=4.909, no_obj=1.499, cls=1.652
# Epoch [3/50], Iter [300/627], Loss: total=1.952, reg=7.535, containing_obj=4.913, no_obj=1.503, cls=1.663
# Epoch [3/50], Iter [350/627], Loss: total=1.968, reg=7.551, containing_obj=4.977, no_obj=1.498, cls=1.720
# Epoch [3/50], Iter [400/627], Loss: total=1.962, reg=7.505, containing_obj=4.968, no_obj=1.500, cls=1.723
# Epoch [3/50], Iter [450/627], Loss: total=1.971, reg=7.515, containing_obj=4.996, no_obj=1.517, cls=1.742
# Epoch [3/50], Iter [500/627], Loss: total=1.982, reg=7.532, containing_obj=5.016, no_obj=1.522, cls=1.788
# Epoch [3/50], Iter [550/627], Loss: total=1.970, reg=7.472, containing_obj=4.986, no_obj=1.523, cls=1.775
# Epoch [3/50], Iter [600/627], Loss: total=1.970, reg=7.471, containing_obj=5.004, no_obj=1.524, cls=1.760
#
#
# Starting epoch 4 / 50
# Learning Rate for this epoch: 0.001
# Epoch [4/50], Iter [50/627], Loss: total=2.078, reg=8.249, containing_obj=4.940, no_obj=1.507, cls=1.931
# Epoch [4/50], Iter [100/627], Loss: total=2.005, reg=7.819, containing_obj=4.921, no_obj=1.462, cls=1.842
# Epoch [4/50], Iter [150/627], Loss: total=2.000, reg=7.642, containing_obj=5.089, no_obj=1.483, cls=1.787
# Epoch [4/50], Iter [200/627], Loss: total=1.999, reg=7.636, containing_obj=5.091, no_obj=1.507, cls=1.755
# Epoch [4/50], Iter [250/627], Loss: total=1.980, reg=7.583, containing_obj=5.038, no_obj=1.521, cls=1.701
# Epoch [4/50], Iter [300/627], Loss: total=1.973, reg=7.549, containing_obj=4.994, no_obj=1.530, cls=1.711
# Epoch [4/50], Iter [350/627], Loss: total=1.985, reg=7.564, containing_obj=5.025, no_obj=1.552, cls=1.735
# Epoch [4/50], Iter [400/627], Loss: total=1.986, reg=7.570, containing_obj=5.028, no_obj=1.568, cls=1.726
# Epoch [4/50], Iter [450/627], Loss: total=1.967, reg=7.448, containing_obj=5.007, no_obj=1.565, cls=1.719
# Epoch [4/50], Iter [500/627], Loss: total=1.956, reg=7.396, containing_obj=4.980, no_obj=1.565, cls=1.703
# Epoch [4/50], Iter [550/627], Loss: total=1.966, reg=7.421, containing_obj=5.019, no_obj=1.554, cls=1.737
# Epoch [4/50], Iter [600/627], Loss: total=1.963, reg=7.423, containing_obj=4.996, no_obj=1.560, cls=1.726
#
#
# Starting epoch 5 / 50
# Learning Rate for this epoch: 0.001
# Epoch [5/50], Iter [50/627], Loss: total=1.991, reg=7.564, containing_obj=5.181, no_obj=1.376, cls=1.810
# Epoch [5/50], Iter [100/627], Loss: total=1.986, reg=7.423, containing_obj=5.230, no_obj=1.417, cls=1.816
# Epoch [5/50], Iter [150/627], Loss: total=1.936, reg=7.220, containing_obj=5.100, no_obj=1.442, cls=1.724
# Epoch [5/50], Iter [200/627], Loss: total=1.960, reg=7.423, containing_obj=5.086, no_obj=1.449, cls=1.723
# Epoch [5/50], Iter [250/627], Loss: total=1.932, reg=7.312, containing_obj=4.979, no_obj=1.464, cls=1.703
# Epoch [5/50], Iter [300/627], Loss: total=1.945, reg=7.379, containing_obj=4.999, no_obj=1.464, cls=1.721
# Epoch [5/50], Iter [350/627], Loss: total=1.938, reg=7.342, containing_obj=4.978, no_obj=1.479, cls=1.705
# Epoch [5/50], Iter [400/627], Loss: total=1.938, reg=7.353, containing_obj=4.950, no_obj=1.487, cls=1.714
# Epoch [5/50], Iter [450/627], Loss: total=1.947, reg=7.395, containing_obj=5.004, no_obj=1.493, cls=1.680
# Epoch [5/50], Iter [500/627], Loss: total=1.952, reg=7.421, containing_obj=4.987, no_obj=1.505, cls=1.700
# Epoch [5/50], Iter [550/627], Loss: total=1.942, reg=7.373, containing_obj=4.951, no_obj=1.506, cls=1.709
# Epoch [5/50], Iter [600/627], Loss: total=1.941, reg=7.383, containing_obj=4.930, no_obj=1.511, cls=1.705
# ---Evaluate model on test samples---
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [02:09<00:00, 38.15it/s]
# ---class aeroplane ap 0.48027260319872345---
# ---class bicycle ap 0.6601371158275703---
# ---class bird ap 0.38624070621031437---
# ---class boat ap 0.32051399514354995---
# ---class bottle ap 0.1784986696410527---
# ---class bus ap 0.623276632924607---
# ---class car ap 0.6383006450413673---
# ---class cat ap 0.6879070368519352---
# ---class chair ap 0.2723186918873418---
# ---class cow ap 0.4655593153757174---
# ---class diningtable ap 0.32510678853807484---
# ---class dog ap 0.6011875080758059---
# ---class horse ap 0.6013828339341694---
# ---class motorbike ap 0.5283609191154686---
# ---class person ap 0.5605328004143579---
# ---class pottedplant ap 0.15435281692470287---
# ---class sheep ap 0.4857010008828496---
# ---class sofa ap 0.4726504403162114---
# ---class train ap 0.6001783124861151---
# ---class tvmonitor ap 0.5278058437184066---
# ---map 0.4785142338254171---
# 4 [0.48027260319872345, 0.6601371158275703, 0.38624070621031437, 0.32051399514354995, 0.1784986696410527, 0.623276632924607, 0.6383006450413673, 0.6879070368519352, 0.2723186918873418, 0.4655593153757174, 0.32510678853807484, 0.6011875080758059, 0.6013828339341694, 0.5283609191154686, 0.5605328004143579, 0.15435281692470287, 0.4857010008828496, 0.4726504403162114, 0.6001783124861151, 0.5278058437184066]
# Updating best test loss: 2.75483
#
#
# Starting epoch 6 / 50
# Learning Rate for this epoch: 0.001
# Epoch [6/50], Iter [50/627], Loss: total=1.876, reg=7.159, containing_obj=4.761, no_obj=1.416, cls=1.669
# Epoch [6/50], Iter [100/627], Loss: total=1.892, reg=7.419, containing_obj=4.652, no_obj=1.427, cls=1.639
# Epoch [6/50], Iter [150/627], Loss: total=1.902, reg=7.380, containing_obj=4.616, no_obj=1.520, cls=1.702
# Epoch [6/50], Iter [200/627], Loss: total=1.931, reg=7.456, containing_obj=4.756, no_obj=1.505, cls=1.728
# Epoch [6/50], Iter [250/627], Loss: total=1.902, reg=7.304, containing_obj=4.688, no_obj=1.530, cls=1.691
# Epoch [6/50], Iter [300/627], Loss: total=1.912, reg=7.299, containing_obj=4.793, no_obj=1.527, cls=1.675
# Epoch [6/50], Iter [350/627], Loss: total=1.900, reg=7.254, containing_obj=4.760, no_obj=1.521, cls=1.663
# Epoch [6/50], Iter [400/627], Loss: total=1.897, reg=7.220, containing_obj=4.769, no_obj=1.524, cls=1.666
# Epoch [6/50], Iter [450/627], Loss: total=1.902, reg=7.252, containing_obj=4.785, no_obj=1.511, cls=1.671
# Epoch [6/50], Iter [500/627], Loss: total=1.903, reg=7.236, containing_obj=4.827, no_obj=1.520, cls=1.637
# Epoch [6/50], Iter [550/627], Loss: total=1.912, reg=7.285, containing_obj=4.853, no_obj=1.519, cls=1.639
# Epoch [6/50], Iter [600/627], Loss: total=1.912, reg=7.277, containing_obj=4.849, no_obj=1.536, cls=1.637
#
#
# Starting epoch 7 / 50
# Learning Rate for this epoch: 0.001
# Epoch [7/50], Iter [50/627], Loss: total=1.868, reg=7.024, containing_obj=4.911, no_obj=1.539, cls=1.467
# Epoch [7/50], Iter [100/627], Loss: total=1.848, reg=7.001, containing_obj=4.801, no_obj=1.557, cls=1.421
# Epoch [7/50], Iter [150/627], Loss: total=1.844, reg=7.040, containing_obj=4.739, no_obj=1.505, cls=1.472
# Epoch [7/50], Iter [200/627], Loss: total=1.875, reg=7.186, containing_obj=4.797, no_obj=1.521, cls=1.495
# Epoch [7/50], Iter [250/627], Loss: total=1.862, reg=7.085, containing_obj=4.795, no_obj=1.520, cls=1.500
# Epoch [7/50], Iter [300/627], Loss: total=1.867, reg=7.086, containing_obj=4.799, no_obj=1.525, cls=1.530
# Epoch [7/50], Iter [350/627], Loss: total=1.866, reg=7.085, containing_obj=4.792, no_obj=1.516, cls=1.534
# Epoch [7/50], Iter [400/627], Loss: total=1.858, reg=7.067, containing_obj=4.746, no_obj=1.519, cls=1.529
# Epoch [7/50], Iter [450/627], Loss: total=1.872, reg=7.089, containing_obj=4.778, no_obj=1.525, cls=1.585
# Epoch [7/50], Iter [500/627], Loss: total=1.884, reg=7.152, containing_obj=4.816, no_obj=1.522, cls=1.582
# Epoch [7/50], Iter [550/627], Loss: total=1.898, reg=7.199, containing_obj=4.854, no_obj=1.542, cls=1.592
# Epoch [7/50], Iter [600/627], Loss: total=1.906, reg=7.235, containing_obj=4.878, no_obj=1.539, cls=1.592
# Updating best test loss: 2.71068
#
#
# Starting epoch 8 / 50
# Learning Rate for this epoch: 0.001
# Epoch [8/50], Iter [50/627], Loss: total=2.007, reg=7.484, containing_obj=5.060, no_obj=1.655, cls=1.861
# Epoch [8/50], Iter [100/627], Loss: total=1.854, reg=6.777, containing_obj=4.889, no_obj=1.582, cls=1.583
# Epoch [8/50], Iter [150/627], Loss: total=1.861, reg=7.012, containing_obj=4.727, no_obj=1.591, cls=1.555
# Epoch [8/50], Iter [200/627], Loss: total=1.883, reg=7.118, containing_obj=4.799, no_obj=1.555, cls=1.593
# Epoch [8/50], Iter [250/627], Loss: total=1.913, reg=7.181, containing_obj=4.910, no_obj=1.547, cls=1.663
# Epoch [8/50], Iter [300/627], Loss: total=1.879, reg=7.081, containing_obj=4.833, no_obj=1.537, cls=1.581
# Epoch [8/50], Iter [350/627], Loss: total=1.890, reg=7.110, containing_obj=4.889, no_obj=1.537, cls=1.581
# Epoch [8/50], Iter [400/627], Loss: total=1.905, reg=7.229, containing_obj=4.899, no_obj=1.533, cls=1.578
# Epoch [8/50], Iter [450/627], Loss: total=1.897, reg=7.226, containing_obj=4.855, no_obj=1.537, cls=1.556
# Epoch [8/50], Iter [500/627], Loss: total=1.901, reg=7.233, containing_obj=4.877, no_obj=1.532, cls=1.568
# Epoch [8/50], Iter [550/627], Loss: total=1.911, reg=7.248, containing_obj=4.894, no_obj=1.539, cls=1.609
# Epoch [8/50], Iter [600/627], Loss: total=1.917, reg=7.270, containing_obj=4.891, no_obj=1.539, cls=1.633
#
#
# Starting epoch 9 / 50
# Learning Rate for this epoch: 0.001
# Epoch [9/50], Iter [50/627], Loss: total=1.725, reg=6.403, containing_obj=4.524, no_obj=1.458, cls=1.417
# Epoch [9/50], Iter [100/627], Loss: total=1.788, reg=6.575, containing_obj=4.705, no_obj=1.545, cls=1.475
# Epoch [9/50], Iter [150/627], Loss: total=1.878, reg=6.993, containing_obj=4.969, no_obj=1.527, cls=1.534
# Epoch [9/50], Iter [200/627], Loss: total=1.876, reg=7.010, containing_obj=4.922, no_obj=1.547, cls=1.530
# Epoch [9/50], Iter [250/627], Loss: total=1.865, reg=6.942, containing_obj=4.907, no_obj=1.541, cls=1.527
# Epoch [9/50], Iter [300/627], Loss: total=1.861, reg=6.979, containing_obj=4.849, no_obj=1.555, cls=1.503
# Epoch [9/50], Iter [350/627], Loss: total=1.862, reg=6.983, containing_obj=4.863, no_obj=1.552, cls=1.500
# Epoch [9/50], Iter [400/627], Loss: total=1.867, reg=7.003, containing_obj=4.871, no_obj=1.544, cls=1.519
# Epoch [9/50], Iter [450/627], Loss: total=1.896, reg=7.109, containing_obj=4.915, no_obj=1.548, cls=1.597
# Epoch [9/50], Iter [500/627], Loss: total=1.897, reg=7.094, containing_obj=4.899, no_obj=1.559, cls=1.621
# Epoch [9/50], Iter [550/627], Loss: total=1.891, reg=7.069, containing_obj=4.870, no_obj=1.563, cls=1.623
# Epoch [9/50], Iter [600/627], Loss: total=1.886, reg=7.051, containing_obj=4.850, no_obj=1.568, cls=1.619
#
#
# Starting epoch 10 / 50
# Learning Rate for this epoch: 0.001
# Epoch [10/50], Iter [50/627], Loss: total=1.643, reg=6.025, containing_obj=4.360, no_obj=1.553, cls=1.205
# Epoch [10/50], Iter [100/627], Loss: total=1.868, reg=6.986, containing_obj=4.986, no_obj=1.561, cls=1.411
# Epoch [10/50], Iter [150/627], Loss: total=1.842, reg=6.972, containing_obj=4.889, no_obj=1.537, cls=1.335
# Epoch [10/50], Iter [200/627], Loss: total=1.845, reg=6.961, containing_obj=4.779, no_obj=1.570, cls=1.451
# Epoch [10/50], Iter [250/627], Loss: total=1.871, reg=7.061, containing_obj=4.799, no_obj=1.586, cls=1.519
# Epoch [10/50], Iter [300/627], Loss: total=1.877, reg=7.028, containing_obj=4.863, no_obj=1.569, cls=1.557
# Epoch [10/50], Iter [350/627], Loss: total=1.892, reg=7.086, containing_obj=4.892, no_obj=1.565, cls=1.593
# Epoch [10/50], Iter [400/627], Loss: total=1.870, reg=6.984, containing_obj=4.855, no_obj=1.560, cls=1.566
# Epoch [10/50], Iter [450/627], Loss: total=1.871, reg=6.979, containing_obj=4.858, no_obj=1.553, cls=1.580
# Epoch [10/50], Iter [500/627], Loss: total=1.875, reg=6.982, containing_obj=4.879, no_obj=1.539, cls=1.597
# Epoch [10/50], Iter [550/627], Loss: total=1.851, reg=6.884, containing_obj=4.842, no_obj=1.533, cls=1.548
# Epoch [10/50], Iter [600/627], Loss: total=1.856, reg=6.908, containing_obj=4.854, no_obj=1.528, cls=1.556
# ---Evaluate model on test samples---
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [02:10<00:00, 38.07it/s]
# ---class aeroplane ap 0.45306807107493163---
# ---class bicycle ap 0.6031199148436923---
# ---class bird ap 0.4366665089787085---
# ---class boat ap 0.2562862904227968---
# ---class bottle ap 0.22573602510302102---
# ---class bus ap 0.5968211915982558---
# ---class car ap 0.6356348248347746---
# ---class cat ap 0.6686293030451655---
# ---class chair ap 0.2933344639406329---
# ---class cow ap 0.540007646631129---
# ---class diningtable ap 0.345083055309979---
# ---class dog ap 0.465720536584587---
# ---class horse ap 0.693405688502286---
# ---class motorbike ap 0.5216900211416011---
# ---class person ap 0.5649454499989359---
# ---class pottedplant ap 0.1849600924079474---
# ---class sheep ap 0.46362846237011013---
# ---class sofa ap 0.435696443410753---
# ---class train ap 0.597070359758239---
# ---class tvmonitor ap 0.4641627843184898---
# ---map 0.4722833567138018---
# 9 [0.45306807107493163, 0.6031199148436923, 0.4366665089787085, 0.2562862904227968, 0.22573602510302102, 0.5968211915982558, 0.6356348248347746, 0.6686293030451655, 0.2933344639406329, 0.540007646631129, 0.345083055309979, 0.465720536584587, 0.693405688502286, 0.5216900211416011, 0.5649454499989359, 0.1849600924079474, 0.46362846237011013, 0.435696443410753, 0.597070359758239, 0.4641627843184898]
#
#
# Starting epoch 11 / 50
# Learning Rate for this epoch: 0.001
# Epoch [11/50], Iter [50/627], Loss: total=1.726, reg=6.252, containing_obj=4.576, no_obj=1.601, cls=1.376
# Epoch [11/50], Iter [100/627], Loss: total=1.816, reg=6.783, containing_obj=4.729, no_obj=1.588, cls=1.428
# Epoch [11/50], Iter [150/627], Loss: total=1.809, reg=6.765, containing_obj=4.727, no_obj=1.578, cls=1.402
# Epoch [11/50], Iter [200/627], Loss: total=1.791, reg=6.701, containing_obj=4.690, no_obj=1.595, cls=1.343
# Epoch [11/50], Iter [250/627], Loss: total=1.805, reg=6.778, containing_obj=4.748, no_obj=1.562, cls=1.352
# Epoch [11/50], Iter [300/627], Loss: total=1.790, reg=6.694, containing_obj=4.705, no_obj=1.566, cls=1.357
# Epoch [11/50], Iter [350/627], Loss: total=1.836, reg=6.834, containing_obj=4.799, no_obj=1.560, cls=1.495
# Epoch [11/50], Iter [400/627], Loss: total=1.822, reg=6.759, containing_obj=4.764, no_obj=1.568, cls=1.485
# Epoch [11/50], Iter [450/627], Loss: total=1.839, reg=6.834, containing_obj=4.809, no_obj=1.580, cls=1.493
# Epoch [11/50], Iter [500/627], Loss: total=1.834, reg=6.811, containing_obj=4.787, no_obj=1.576, cls=1.498
# Epoch [11/50], Iter [550/627], Loss: total=1.829, reg=6.802, containing_obj=4.769, no_obj=1.567, cls=1.497
# Epoch [11/50], Iter [600/627], Loss: total=1.844, reg=6.868, containing_obj=4.794, no_obj=1.565, cls=1.524
#
#
# Starting epoch 12 / 50
# Learning Rate for this epoch: 0.001
# Epoch [12/50], Iter [50/627], Loss: total=1.878, reg=6.864, containing_obj=5.107, no_obj=1.641, cls=1.412
# Epoch [12/50], Iter [100/627], Loss: total=1.833, reg=6.925, containing_obj=4.836, no_obj=1.585, cls=1.320
# Epoch [12/50], Iter [150/627], Loss: total=1.871, reg=7.102, containing_obj=4.907, no_obj=1.613, cls=1.344
# Epoch [12/50], Iter [200/627], Loss: total=1.831, reg=6.873, containing_obj=4.820, no_obj=1.612, cls=1.343
# Epoch [12/50], Iter [250/627], Loss: total=1.845, reg=6.908, containing_obj=4.870, no_obj=1.594, cls=1.390
# Epoch [12/50], Iter [300/627], Loss: total=1.844, reg=6.868, containing_obj=4.878, no_obj=1.598, cls=1.409
# Epoch [12/50], Iter [350/627], Loss: total=1.818, reg=6.735, containing_obj=4.815, no_obj=1.586, cls=1.409
# Epoch [12/50], Iter [400/627], Loss: total=1.821, reg=6.743, containing_obj=4.817, no_obj=1.579, cls=1.428
# Epoch [12/50], Iter [450/627], Loss: total=1.819, reg=6.739, containing_obj=4.804, no_obj=1.581, cls=1.431
# Epoch [12/50], Iter [500/627], Loss: total=1.813, reg=6.715, containing_obj=4.771, no_obj=1.577, cls=1.445
# Epoch [12/50], Iter [550/627], Loss: total=1.810, reg=6.738, containing_obj=4.742, no_obj=1.573, cls=1.424
# Epoch [12/50], Iter [600/627], Loss: total=1.809, reg=6.725, containing_obj=4.746, no_obj=1.579, cls=1.424
#
#
# Starting epoch 13 / 50
# Learning Rate for this epoch: 0.001
# Epoch [13/50], Iter [50/627], Loss: total=1.748, reg=6.725, containing_obj=4.394, no_obj=1.449, cls=1.412
# Epoch [13/50], Iter [100/627], Loss: total=1.725, reg=6.381, containing_obj=4.606, no_obj=1.534, cls=1.283
# Epoch [13/50], Iter [150/627], Loss: total=1.756, reg=6.484, containing_obj=4.723, no_obj=1.502, cls=1.343
# Epoch [13/50], Iter [200/627], Loss: total=1.778, reg=6.630, containing_obj=4.660, no_obj=1.510, cls=1.427
# Epoch [13/50], Iter [250/627], Loss: total=1.757, reg=6.524, containing_obj=4.641, no_obj=1.509, cls=1.384
# Epoch [13/50], Iter [300/627], Loss: total=1.747, reg=6.441, containing_obj=4.616, no_obj=1.511, cls=1.408
# Epoch [13/50], Iter [350/627], Loss: total=1.776, reg=6.583, containing_obj=4.682, no_obj=1.512, cls=1.429
# Epoch [13/50], Iter [400/627], Loss: total=1.776, reg=6.577, containing_obj=4.689, no_obj=1.530, cls=1.414
# Epoch [13/50], Iter [450/627], Loss: total=1.784, reg=6.618, containing_obj=4.687, no_obj=1.538, cls=1.427
# Epoch [13/50], Iter [500/627], Loss: total=1.782, reg=6.634, containing_obj=4.668, no_obj=1.542, cls=1.410
# Epoch [13/50], Iter [550/627], Loss: total=1.791, reg=6.696, containing_obj=4.674, no_obj=1.549, cls=1.410
# Epoch [13/50], Iter [600/627], Loss: total=1.794, reg=6.700, containing_obj=4.669, no_obj=1.559, cls=1.420
#
#
# Starting epoch 14 / 50
# Learning Rate for this epoch: 0.001
# Epoch [14/50], Iter [50/627], Loss: total=1.813, reg=6.812, containing_obj=4.489, no_obj=1.600, cls=1.605
# Epoch [14/50], Iter [100/627], Loss: total=1.812, reg=6.882, containing_obj=4.597, no_obj=1.563, cls=1.456
# Epoch [14/50], Iter [150/627], Loss: total=1.773, reg=6.723, containing_obj=4.511, no_obj=1.542, cls=1.408
# Epoch [14/50], Iter [200/627], Loss: total=1.765, reg=6.725, containing_obj=4.458, no_obj=1.546, cls=1.389
# Epoch [14/50], Iter [250/627], Loss: total=1.759, reg=6.687, containing_obj=4.465, no_obj=1.560, cls=1.360
# Epoch [14/50], Iter [300/627], Loss: total=1.773, reg=6.766, containing_obj=4.510, no_obj=1.552, cls=1.359
# Epoch [14/50], Iter [350/627], Loss: total=1.777, reg=6.787, containing_obj=4.565, no_obj=1.538, cls=1.328
# Epoch [14/50], Iter [400/627], Loss: total=1.779, reg=6.816, containing_obj=4.552, no_obj=1.542, cls=1.323
# Epoch [14/50], Iter [450/627], Loss: total=1.777, reg=6.793, containing_obj=4.562, no_obj=1.541, cls=1.318
# Epoch [14/50], Iter [500/627], Loss: total=1.772, reg=6.749, containing_obj=4.555, no_obj=1.557, cls=1.313
# Epoch [14/50], Iter [550/627], Loss: total=1.768, reg=6.741, containing_obj=4.546, no_obj=1.545, cls=1.313
# Epoch [14/50], Iter [600/627], Loss: total=1.771, reg=6.749, containing_obj=4.568, no_obj=1.544, cls=1.307
#
#
# Starting epoch 15 / 50
# Learning Rate for this epoch: 0.001
# Epoch [15/50], Iter [50/627], Loss: total=1.658, reg=6.168, containing_obj=4.416, no_obj=1.544, cls=1.135
# Epoch [15/50], Iter [100/627], Loss: total=1.721, reg=6.446, containing_obj=4.630, no_obj=1.540, cls=1.152
# Epoch [15/50], Iter [150/627], Loss: total=1.695, reg=6.231, containing_obj=4.598, no_obj=1.504, cls=1.227
# Epoch [15/50], Iter [200/627], Loss: total=1.731, reg=6.376, containing_obj=4.654, no_obj=1.539, cls=1.277
# Epoch [15/50], Iter [250/627], Loss: total=1.749, reg=6.474, containing_obj=4.660, no_obj=1.538, cls=1.322
# Epoch [15/50], Iter [300/627], Loss: total=1.733, reg=6.380, containing_obj=4.617, no_obj=1.530, cls=1.341
# Epoch [15/50], Iter [350/627], Loss: total=1.741, reg=6.417, containing_obj=4.613, no_obj=1.517, cls=1.384
# Epoch [15/50], Iter [400/627], Loss: total=1.736, reg=6.385, containing_obj=4.561, no_obj=1.529, cls=1.415
# Epoch [15/50], Iter [450/627], Loss: total=1.760, reg=6.502, containing_obj=4.609, no_obj=1.533, cls=1.440
# Epoch [15/50], Iter [500/627], Loss: total=1.774, reg=6.555, containing_obj=4.645, no_obj=1.538, cls=1.453
# Epoch [15/50], Iter [550/627], Loss: total=1.776, reg=6.543, containing_obj=4.677, no_obj=1.538, cls=1.449
# Epoch [15/50], Iter [600/627], Loss: total=1.765, reg=6.492, containing_obj=4.660, no_obj=1.536, cls=1.431
# ---Evaluate model on test samples---
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [02:10<00:00, 37.96it/s]
# ---class aeroplane ap 0.46248347944910373---
# ---class bicycle ap 0.5654389643517883---
# ---class bird ap 0.4351906803331824---
# ---class boat ap 0.220489013709199---
# ---class bottle ap 0.16764855441241766---
# ---class bus ap 0.5666500846870774---
# ---class car ap 0.6231746448284041---
# ---class cat ap 0.6467874783774138---
# ---class chair ap 0.2702955371698144---
# ---class cow ap 0.5360380172070438---
# ---class diningtable ap 0.32496133576560626---
# ---class dog ap 0.56810483664543---
# ---class horse ap 0.6867162320875015---
# ---class motorbike ap 0.5093714215228765---
# ---class person ap 0.5374321594254002---
# ---class pottedplant ap 0.15634102912825623---
# ---class sheep ap 0.4345934741427369---
# ---class sofa ap 0.4162822156840371---
# ---class train ap 0.5987331295474393---
# ---class tvmonitor ap 0.46185934040893073---
# ---map 0.45942958144418294---
# 14 [0.46248347944910373, 0.5654389643517883, 0.4351906803331824, 0.220489013709199, 0.16764855441241766, 0.5666500846870774, 0.6231746448284041, 0.6467874783774138, 0.2702955371698144, 0.5360380172070438, 0.32496133576560626, 0.56810483664543, 0.6867162320875015, 0.5093714215228765, 0.5374321594254002, 0.15634102912825623, 0.4345934741427369, 0.4162822156840371, 0.5987331295474393, 0.46185934040893073]
#
#
# Starting epoch 16 / 50
# Learning Rate for this epoch: 0.001
# Epoch [16/50], Iter [50/627], Loss: total=1.746, reg=6.355, containing_obj=4.692, no_obj=1.649, cls=1.276
# Epoch [16/50], Iter [100/627], Loss: total=1.754, reg=6.383, containing_obj=4.628, no_obj=1.573, cls=1.447
# Epoch [16/50], Iter [150/627], Loss: total=1.781, reg=6.595, containing_obj=4.618, no_obj=1.563, cls=1.471
# Epoch [16/50], Iter [200/627], Loss: total=1.771, reg=6.616, containing_obj=4.530, no_obj=1.554, cls=1.469
# Epoch [16/50], Iter [250/627], Loss: total=1.752, reg=6.581, containing_obj=4.458, no_obj=1.555, cls=1.425
# Epoch [16/50], Iter [300/627], Loss: total=1.765, reg=6.654, containing_obj=4.520, no_obj=1.545, cls=1.404
# Epoch [16/50], Iter [350/627], Loss: total=1.775, reg=6.687, containing_obj=4.527, no_obj=1.556, cls=1.426
# Epoch [16/50], Iter [400/627], Loss: total=1.764, reg=6.666, containing_obj=4.525, no_obj=1.550, cls=1.374
# Epoch [16/50], Iter [450/627], Loss: total=1.775, reg=6.710, containing_obj=4.538, no_obj=1.549, cls=1.403
# Epoch [16/50], Iter [500/627], Loss: total=1.764, reg=6.657, containing_obj=4.501, no_obj=1.558, cls=1.393
# Epoch [16/50], Iter [550/627], Loss: total=1.782, reg=6.721, containing_obj=4.553, no_obj=1.561, cls=1.419
# Epoch [16/50], Iter [600/627], Loss: total=1.784, reg=6.706, containing_obj=4.580, no_obj=1.569, cls=1.416
#
#
# Starting epoch 17 / 50
# Learning Rate for this epoch: 0.001
# Epoch [17/50], Iter [50/627], Loss: total=1.737, reg=6.570, containing_obj=4.511, no_obj=1.562, cls=1.251
# Epoch [17/50], Iter [100/627], Loss: total=1.686, reg=6.308, containing_obj=4.448, no_obj=1.541, cls=1.194
# Epoch [17/50], Iter [150/627], Loss: total=1.714, reg=6.426, containing_obj=4.432, no_obj=1.533, cls=1.324
# Epoch [17/50], Iter [200/627], Loss: total=1.720, reg=6.415, containing_obj=4.509, no_obj=1.555, cls=1.281
# Epoch [17/50], Iter [250/627], Loss: total=1.717, reg=6.383, containing_obj=4.480, no_obj=1.564, cls=1.312
# Epoch [17/50], Iter [300/627], Loss: total=1.751, reg=6.567, containing_obj=4.542, no_obj=1.568, cls=1.331
# Epoch [17/50], Iter [350/627], Loss: total=1.746, reg=6.549, containing_obj=4.507, no_obj=1.561, cls=1.348
# Epoch [17/50], Iter [400/627], Loss: total=1.736, reg=6.499, containing_obj=4.465, no_obj=1.557, cls=1.366
# Epoch [17/50], Iter [450/627], Loss: total=1.748, reg=6.547, containing_obj=4.503, no_obj=1.559, cls=1.374
# Epoch [17/50], Iter [500/627], Loss: total=1.752, reg=6.561, containing_obj=4.489, no_obj=1.574, cls=1.390
# Epoch [17/50], Iter [550/627], Loss: total=1.755, reg=6.555, containing_obj=4.526, no_obj=1.570, cls=1.387
# Epoch [17/50], Iter [600/627], Loss: total=1.776, reg=6.646, containing_obj=4.565, no_obj=1.575, cls=1.423
#
#
# Starting epoch 18 / 50
# Learning Rate for this epoch: 0.001
# Epoch [18/50], Iter [50/627], Loss: total=1.905, reg=7.328, containing_obj=4.751, no_obj=1.620, cls=1.539
# Epoch [18/50], Iter [100/627], Loss: total=1.778, reg=6.555, containing_obj=4.517, no_obj=1.626, cls=1.531
# Epoch [18/50], Iter [150/627], Loss: total=1.763, reg=6.555, containing_obj=4.454, no_obj=1.637, cls=1.461
# Epoch [18/50], Iter [200/627], Loss: total=1.713, reg=6.374, containing_obj=4.429, no_obj=1.587, cls=1.312
# Epoch [18/50], Iter [250/627], Loss: total=1.701, reg=6.423, containing_obj=4.351, no_obj=1.588, cls=1.249
# Epoch [18/50], Iter [300/627], Loss: total=1.688, reg=6.365, containing_obj=4.321, no_obj=1.579, cls=1.242
# Epoch [18/50], Iter [350/627], Loss: total=1.697, reg=6.428, containing_obj=4.344, no_obj=1.580, cls=1.226
# Epoch [18/50], Iter [400/627], Loss: total=1.712, reg=6.443, containing_obj=4.395, no_obj=1.574, cls=1.281
# Epoch [18/50], Iter [450/627], Loss: total=1.711, reg=6.459, containing_obj=4.398, no_obj=1.574, cls=1.255
# Epoch [18/50], Iter [500/627], Loss: total=1.726, reg=6.519, containing_obj=4.446, no_obj=1.571, cls=1.270
# Epoch [18/50], Iter [550/627], Loss: total=1.723, reg=6.496, containing_obj=4.442, no_obj=1.575, cls=1.274
# Epoch [18/50], Iter [600/627], Loss: total=1.731, reg=6.522, containing_obj=4.469, no_obj=1.571, cls=1.291
#
#
# Starting epoch 19 / 50
# Learning Rate for this epoch: 0.001
# Epoch [19/50], Iter [50/627], Loss: total=1.635, reg=5.932, containing_obj=4.374, no_obj=1.638, cls=1.133
# Epoch [19/50], Iter [100/627], Loss: total=1.638, reg=5.946, containing_obj=4.362, no_obj=1.623, cls=1.174
# Epoch [19/50], Iter [150/627], Loss: total=1.688, reg=6.244, containing_obj=4.417, no_obj=1.622, cls=1.221
# Epoch [19/50], Iter [200/627], Loss: total=1.666, reg=6.077, containing_obj=4.417, no_obj=1.604, cls=1.230
# Epoch [19/50], Iter [250/627], Loss: total=1.666, reg=6.126, containing_obj=4.372, no_obj=1.592, cls=1.242
# Epoch [19/50], Iter [300/627], Loss: total=1.677, reg=6.115, containing_obj=4.443, no_obj=1.582, cls=1.279
# Epoch [19/50], Iter [350/627], Loss: total=1.687, reg=6.183, containing_obj=4.450, no_obj=1.574, cls=1.289
# Epoch [19/50], Iter [400/627], Loss: total=1.695, reg=6.213, containing_obj=4.483, no_obj=1.566, cls=1.295
# Epoch [19/50], Iter [450/627], Loss: total=1.696, reg=6.221, containing_obj=4.464, no_obj=1.578, cls=1.308
# Epoch [19/50], Iter [500/627], Loss: total=1.696, reg=6.237, containing_obj=4.457, no_obj=1.568, cls=1.308
# Epoch [19/50], Iter [550/627], Loss: total=1.718, reg=6.349, containing_obj=4.507, no_obj=1.563, cls=1.321
# Epoch [19/50], Iter [600/627], Loss: total=1.726, reg=6.368, containing_obj=4.532, no_obj=1.568, cls=1.343
#
#
# Starting epoch 20 / 50
# Learning Rate for this epoch: 0.001
# Epoch [20/50], Iter [50/627], Loss: total=1.637, reg=5.902, containing_obj=4.212, no_obj=1.555, cls=1.424
# Epoch [20/50], Iter [100/627], Loss: total=1.686, reg=6.154, containing_obj=4.338, no_obj=1.559, cls=1.441
# Epoch [20/50], Iter [150/627], Loss: total=1.682, reg=6.113, containing_obj=4.442, no_obj=1.553, cls=1.346
# Epoch [20/50], Iter [200/627], Loss: total=1.699, reg=6.281, containing_obj=4.438, no_obj=1.585, cls=1.292
# Epoch [20/50], Iter [250/627], Loss: total=1.703, reg=6.325, containing_obj=4.430, no_obj=1.571, cls=1.297
# Epoch [20/50], Iter [300/627], Loss: total=1.712, reg=6.350, containing_obj=4.453, no_obj=1.583, cls=1.312
# Epoch [20/50], Iter [350/627], Loss: total=1.726, reg=6.411, containing_obj=4.466, no_obj=1.591, cls=1.340
# Epoch [20/50], Iter [400/627], Loss: total=1.722, reg=6.382, containing_obj=4.450, no_obj=1.596, cls=1.349
# Epoch [20/50], Iter [450/627], Loss: total=1.711, reg=6.340, containing_obj=4.424, no_obj=1.594, cls=1.333
# Epoch [20/50], Iter [500/627], Loss: total=1.709, reg=6.321, containing_obj=4.433, no_obj=1.592, cls=1.323
# Epoch [20/50], Iter [550/627], Loss: total=1.714, reg=6.344, containing_obj=4.437, no_obj=1.587, cls=1.342
# Epoch [20/50], Iter [600/627], Loss: total=1.714, reg=6.359, containing_obj=4.444, no_obj=1.575, cls=1.335
# ---Evaluate model on test samples---
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [02:08<00:00, 38.43it/s]
# ---class aeroplane ap 0.4374534730642129---
# ---class bicycle ap 0.6189195305801062---
# ---class bird ap 0.4789663391724595---
# ---class boat ap 0.28408233546400896---
# ---class bottle ap 0.20504861067814922---
# ---class bus ap 0.6321854218996397---
# ---class car ap 0.6743551704986563---
# ---class cat ap 0.6343822395569088---
# ---class chair ap 0.31295215184230935---
# ---class cow ap 0.4845876509147483---
# ---class diningtable ap 0.40129578601130084---
# ---class dog ap 0.6281053399642207---
# ---class horse ap 0.6164116543932285---
# ---class motorbike ap 0.537851506688281---
# ---class person ap 0.5753829567934738---
# ---class pottedplant ap 0.17174634127554236---
# ---class sheep ap 0.42279653464020195---
# ---class sofa ap 0.4490801525926465---
# ---class train ap 0.6443435664015074---
# ---class tvmonitor ap 0.461130999900087---
# ---map 0.4835538881165845---
# 19 [0.4374534730642129, 0.6189195305801062, 0.4789663391724595, 0.28408233546400896, 0.20504861067814922, 0.6321854218996397, 0.6743551704986563, 0.6343822395569088, 0.31295215184230935, 0.4845876509147483, 0.40129578601130084, 0.6281053399642207, 0.6164116543932285, 0.537851506688281, 0.5753829567934738, 0.17174634127554236, 0.42279653464020195, 0.4490801525926465, 0.6443435664015074, 0.461130999900087]
#
#
# Starting epoch 21 / 50
# Learning Rate for this epoch: 0.001
# Epoch [21/50], Iter [50/627], Loss: total=1.759, reg=6.429, containing_obj=4.667, no_obj=1.590, cls=1.384
# Epoch [21/50], Iter [100/627], Loss: total=1.798, reg=6.688, containing_obj=4.697, no_obj=1.609, cls=1.387
# Epoch [21/50], Iter [150/627], Loss: total=1.783, reg=6.681, containing_obj=4.660, no_obj=1.617, cls=1.305
# Epoch [21/50], Iter [200/627], Loss: total=1.753, reg=6.450, containing_obj=4.596, no_obj=1.627, cls=1.353
# Epoch [21/50], Iter [250/627], Loss: total=1.794, reg=6.659, containing_obj=4.702, no_obj=1.599, cls=1.396
# Epoch [21/50], Iter [300/627], Loss: total=1.779, reg=6.621, containing_obj=4.661, no_obj=1.580, cls=1.370
# Epoch [21/50], Iter [350/627], Loss: total=1.769, reg=6.579, containing_obj=4.631, no_obj=1.582, cls=1.363
# Epoch [21/50], Iter [400/627], Loss: total=1.757, reg=6.513, containing_obj=4.602, no_obj=1.570, cls=1.374
# Epoch [21/50], Iter [450/627], Loss: total=1.756, reg=6.493, containing_obj=4.591, no_obj=1.589, cls=1.374
# Epoch [21/50], Iter [500/627], Loss: total=1.734, reg=6.405, containing_obj=4.536, no_obj=1.579, cls=1.351
# Epoch [21/50], Iter [550/627], Loss: total=1.725, reg=6.373, containing_obj=4.503, no_obj=1.571, cls=1.354
# Epoch [21/50], Iter [600/627], Loss: total=1.743, reg=6.462, containing_obj=4.541, no_obj=1.573, cls=1.369
#
#
# Starting epoch 22 / 50
# Learning Rate for this epoch: 0.001
# Epoch [22/50], Iter [50/627], Loss: total=1.818, reg=6.850, containing_obj=4.672, no_obj=1.565, cls=1.459
# Epoch [22/50], Iter [100/627], Loss: total=1.747, reg=6.458, containing_obj=4.512, no_obj=1.577, cls=1.427
# Epoch [22/50], Iter [150/627], Loss: total=1.720, reg=6.335, containing_obj=4.485, no_obj=1.534, cls=1.408
# Epoch [22/50], Iter [200/627], Loss: total=1.685, reg=6.201, containing_obj=4.447, no_obj=1.524, cls=1.309
# Epoch [22/50], Iter [250/627], Loss: total=1.673, reg=6.121, containing_obj=4.425, no_obj=1.513, cls=1.321
# Epoch [22/50], Iter [300/627], Loss: total=1.676, reg=6.172, containing_obj=4.427, no_obj=1.532, cls=1.275
# Epoch [22/50], Iter [350/627], Loss: total=1.675, reg=6.154, containing_obj=4.427, no_obj=1.530, cls=1.291
# Epoch [22/50], Iter [400/627], Loss: total=1.670, reg=6.127, containing_obj=4.403, no_obj=1.537, cls=1.296
# Epoch [22/50], Iter [450/627], Loss: total=1.686, reg=6.225, containing_obj=4.438, no_obj=1.543, cls=1.283
# Epoch [22/50], Iter [500/627], Loss: total=1.696, reg=6.263, containing_obj=4.452, no_obj=1.546, cls=1.307
# Epoch [22/50], Iter [550/627], Loss: total=1.714, reg=6.352, containing_obj=4.464, no_obj=1.556, cls=1.337
# Epoch [22/50], Iter [600/627], Loss: total=1.703, reg=6.311, containing_obj=4.442, no_obj=1.561, cls=1.311
#
#
# Starting epoch 23 / 50
# Learning Rate for this epoch: 0.001
# Epoch [23/50], Iter [50/627], Loss: total=1.639, reg=6.039, containing_obj=4.280, no_obj=1.484, cls=1.312
# Epoch [23/50], Iter [100/627], Loss: total=1.673, reg=6.164, containing_obj=4.441, no_obj=1.486, cls=1.297
# Epoch [23/50], Iter [150/627], Loss: total=1.668, reg=6.187, containing_obj=4.355, no_obj=1.548, cls=1.252
# Epoch [23/50], Iter [200/627], Loss: total=1.685, reg=6.313, containing_obj=4.365, no_obj=1.571, cls=1.230
# Epoch [23/50], Iter [250/627], Loss: total=1.695, reg=6.347, containing_obj=4.396, no_obj=1.559, cls=1.256
# Epoch [23/50], Iter [300/627], Loss: total=1.706, reg=6.383, containing_obj=4.400, no_obj=1.567, cls=1.295
# Epoch [23/50], Iter [350/627], Loss: total=1.713, reg=6.420, containing_obj=4.435, no_obj=1.559, cls=1.288
# Epoch [23/50], Iter [400/627], Loss: total=1.726, reg=6.477, containing_obj=4.475, no_obj=1.568, cls=1.286
# Epoch [23/50], Iter [450/627], Loss: total=1.719, reg=6.444, containing_obj=4.455, no_obj=1.583, cls=1.273
# Epoch [23/50], Iter [500/627], Loss: total=1.728, reg=6.447, containing_obj=4.483, no_obj=1.583, cls=1.314
# Epoch [23/50], Iter [550/627], Loss: total=1.716, reg=6.377, containing_obj=4.453, no_obj=1.585, cls=1.310
# Epoch [23/50], Iter [600/627], Loss: total=1.706, reg=6.329, containing_obj=4.430, no_obj=1.589, cls=1.297
#
#
# Starting epoch 24 / 50
# Learning Rate for this epoch: 0.001
# Epoch [24/50], Iter [50/627], Loss: total=1.773, reg=6.575, containing_obj=4.513, no_obj=1.638, cls=1.454
# Epoch [24/50], Iter [100/627], Loss: total=1.759, reg=6.480, containing_obj=4.472, no_obj=1.653, cls=1.469
# Epoch [24/50], Iter [150/627], Loss: total=1.736, reg=6.400, containing_obj=4.508, no_obj=1.620, cls=1.358
# Epoch [24/50], Iter [200/627], Loss: total=1.718, reg=6.378, containing_obj=4.408, no_obj=1.612, cls=1.349
# Epoch [24/50], Iter [250/627], Loss: total=1.684, reg=6.288, containing_obj=4.317, no_obj=1.578, cls=1.291
# Epoch [24/50], Iter [300/627], Loss: total=1.676, reg=6.272, containing_obj=4.310, no_obj=1.558, cls=1.266
# Epoch [24/50], Iter [350/627], Loss: total=1.687, reg=6.275, containing_obj=4.372, no_obj=1.567, cls=1.284
# Epoch [24/50], Iter [400/627], Loss: total=1.680, reg=6.212, containing_obj=4.359, no_obj=1.571, cls=1.299
# Epoch [24/50], Iter [450/627], Loss: total=1.679, reg=6.202, containing_obj=4.386, no_obj=1.570, cls=1.271
# Epoch [24/50], Iter [500/627], Loss: total=1.685, reg=6.242, containing_obj=4.413, no_obj=1.555, cls=1.268
# Epoch [24/50], Iter [550/627], Loss: total=1.683, reg=6.232, containing_obj=4.432, no_obj=1.554, cls=1.248
# Epoch [24/50], Iter [600/627], Loss: total=1.677, reg=6.195, containing_obj=4.408, no_obj=1.557, cls=1.257
#
#
# Starting epoch 25 / 50
# Learning Rate for this epoch: 0.001
# Epoch [25/50], Iter [50/627], Loss: total=1.588, reg=5.813, containing_obj=4.235, no_obj=1.582, cls=1.072
# Epoch [25/50], Iter [100/627], Loss: total=1.513, reg=5.547, containing_obj=4.033, no_obj=1.548, cls=0.976
# Epoch [25/50], Iter [150/627], Loss: total=1.567, reg=5.713, containing_obj=4.166, no_obj=1.573, cls=1.085
# Epoch [25/50], Iter [200/627], Loss: total=1.627, reg=5.942, containing_obj=4.337, no_obj=1.587, cls=1.147
# Epoch [25/50], Iter [250/627], Loss: total=1.625, reg=5.941, containing_obj=4.288, no_obj=1.599, cls=1.175
# Epoch [25/50], Iter [300/627], Loss: total=1.610, reg=5.865, containing_obj=4.277, no_obj=1.563, cls=1.174
# Epoch [25/50], Iter [350/627], Loss: total=1.617, reg=5.912, containing_obj=4.310, no_obj=1.564, cls=1.150
# Epoch [25/50], Iter [400/627], Loss: total=1.614, reg=5.900, containing_obj=4.299, no_obj=1.556, cls=1.158
# Epoch [25/50], Iter [450/627], Loss: total=1.618, reg=5.920, containing_obj=4.302, no_obj=1.551, cls=1.175
# Epoch [25/50], Iter [500/627], Loss: total=1.630, reg=5.966, containing_obj=4.334, no_obj=1.549, cls=1.194
# Epoch [25/50], Iter [550/627], Loss: total=1.636, reg=5.999, containing_obj=4.326, no_obj=1.552, cls=1.208
# Epoch [25/50], Iter [600/627], Loss: total=1.646, reg=6.056, containing_obj=4.332, no_obj=1.573, cls=1.207
# ---Evaluate model on test samples---
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [02:09<00:00, 38.30it/s]
# ---class aeroplane ap 0.4513593922452678---
# ---class bicycle ap 0.5311792546840457---
# ---class bird ap 0.40060403725176796---
# ---class boat ap 0.2533680552115282---
# ---class bottle ap 0.1945674566525521---
# ---class bus ap 0.6141366257531422---
# ---class car ap 0.6606451177757042---
# ---class cat ap 0.6771695951390786---
# ---class chair ap 0.2744199567932969---
# ---class cow ap 0.504969296829328---
# ---class diningtable ap 0.42667315538181044---
# ---class dog ap 0.5856176934661859---
# ---class horse ap 0.6514319204537034---
# ---class motorbike ap 0.5141290986458696---
# ---class person ap 0.5482479022725397---
# ---class pottedplant ap 0.17598083876022858---
# ---class sheep ap 0.45144589913408045---
# ---class sofa ap 0.4370540454033713---
# ---class train ap 0.6665391929467349---
# ---class tvmonitor ap 0.4562388103377703---
# ---map 0.4737888672569003---
# 24 [0.4513593922452678, 0.5311792546840457, 0.40060403725176796, 0.2533680552115282, 0.1945674566525521, 0.6141366257531422, 0.6606451177757042, 0.6771695951390786, 0.2744199567932969, 0.504969296829328, 0.42667315538181044, 0.5856176934661859, 0.6514319204537034, 0.5141290986458696, 0.5482479022725397, 0.17598083876022858, 0.45144589913408045, 0.4370540454033713, 0.6665391929467349, 0.4562388103377703]
#
#
# Starting epoch 26 / 50
# Learning Rate for this epoch: 0.001
# Epoch [26/50], Iter [50/627], Loss: total=1.701, reg=6.067, containing_obj=4.745, no_obj=1.474, cls=1.320
# Epoch [26/50], Iter [100/627], Loss: total=1.670, reg=6.041, containing_obj=4.599, no_obj=1.509, cls=1.211
# Epoch [26/50], Iter [150/627], Loss: total=1.644, reg=5.938, containing_obj=4.454, no_obj=1.573, cls=1.184
# Epoch [26/50], Iter [200/627], Loss: total=1.679, reg=6.082, containing_obj=4.472, no_obj=1.619, cls=1.256
# Epoch [26/50], Iter [250/627], Loss: total=1.675, reg=6.046, containing_obj=4.482, no_obj=1.615, cls=1.255
# Epoch [26/50], Iter [300/627], Loss: total=1.668, reg=6.032, containing_obj=4.437, no_obj=1.620, cls=1.254
# Epoch [26/50], Iter [350/627], Loss: total=1.663, reg=5.975, containing_obj=4.433, no_obj=1.606, cls=1.288
# Epoch [26/50], Iter [400/627], Loss: total=1.662, reg=5.984, containing_obj=4.438, no_obj=1.620, cls=1.256
# Epoch [26/50], Iter [450/627], Loss: total=1.653, reg=5.981, containing_obj=4.409, no_obj=1.603, cls=1.234
# Epoch [26/50], Iter [500/627], Loss: total=1.664, reg=6.047, containing_obj=4.425, no_obj=1.614, cls=1.223
# Epoch [26/50], Iter [550/627], Loss: total=1.652, reg=6.010, containing_obj=4.392, no_obj=1.613, cls=1.202
# Epoch [26/50], Iter [600/627], Loss: total=1.648, reg=6.006, containing_obj=4.373, no_obj=1.606, cls=1.199
#
#
# Starting epoch 27 / 50
# Learning Rate for this epoch: 0.001
# Epoch [27/50], Iter [50/627], Loss: total=1.578, reg=5.914, containing_obj=4.193, no_obj=1.498, cls=1.020
# Epoch [27/50], Iter [100/627], Loss: total=1.595, reg=5.874, containing_obj=4.286, no_obj=1.522, cls=1.076
# Epoch [27/50], Iter [150/627], Loss: total=1.606, reg=6.026, containing_obj=4.120, no_obj=1.519, cls=1.185
# Epoch [27/50], Iter [200/627], Loss: total=1.620, reg=6.011, containing_obj=4.202, no_obj=1.551, cls=1.193
# Epoch [27/50], Iter [250/627], Loss: total=1.627, reg=6.045, containing_obj=4.261, no_obj=1.539, cls=1.169
# Epoch [27/50], Iter [300/627], Loss: total=1.621, reg=5.976, containing_obj=4.262, no_obj=1.536, cls=1.193
# Epoch [27/50], Iter [350/627], Loss: total=1.620, reg=5.929, containing_obj=4.290, no_obj=1.552, cls=1.191
# Epoch [27/50], Iter [400/627], Loss: total=1.605, reg=5.879, containing_obj=4.260, no_obj=1.552, cls=1.149
# Epoch [27/50], Iter [450/627], Loss: total=1.605, reg=5.897, containing_obj=4.248, no_obj=1.543, cls=1.155
# Epoch [27/50], Iter [500/627], Loss: total=1.617, reg=5.949, containing_obj=4.263, no_obj=1.549, cls=1.171
# Epoch [27/50], Iter [550/627], Loss: total=1.623, reg=5.966, containing_obj=4.270, no_obj=1.562, cls=1.183
# Epoch [27/50], Iter [600/627], Loss: total=1.637, reg=6.014, containing_obj=4.296, no_obj=1.555, cls=1.230
#
#
# Starting epoch 28 / 50
# Learning Rate for this epoch: 0.001
# Epoch [28/50], Iter [50/627], Loss: total=1.780, reg=6.801, containing_obj=4.435, no_obj=1.618, cls=1.383
# Epoch [28/50], Iter [100/627], Loss: total=1.657, reg=6.167, containing_obj=4.208, no_obj=1.595, cls=1.288
# Epoch [28/50], Iter [150/627], Loss: total=1.643, reg=6.225, containing_obj=4.120, no_obj=1.571, cls=1.226
# Epoch [28/50], Iter [200/627], Loss: total=1.642, reg=6.180, containing_obj=4.177, no_obj=1.562, cls=1.214
# Epoch [28/50], Iter [250/627], Loss: total=1.619, reg=6.054, containing_obj=4.148, no_obj=1.572, cls=1.176
# Epoch [28/50], Iter [300/627], Loss: total=1.591, reg=5.908, containing_obj=4.130, no_obj=1.559, cls=1.131
# Epoch [28/50], Iter [350/627], Loss: total=1.581, reg=5.888, containing_obj=4.124, no_obj=1.555, cls=1.082
# Epoch [28/50], Iter [400/627], Loss: total=1.580, reg=5.892, containing_obj=4.111, no_obj=1.554, cls=1.087
# Epoch [28/50], Iter [450/627], Loss: total=1.582, reg=5.883, containing_obj=4.118, no_obj=1.548, cls=1.105
# Epoch [28/50], Iter [500/627], Loss: total=1.589, reg=5.888, containing_obj=4.133, no_obj=1.559, cls=1.130
# Epoch [28/50], Iter [550/627], Loss: total=1.598, reg=5.916, containing_obj=4.178, no_obj=1.555, cls=1.139
# Epoch [28/50], Iter [600/627], Loss: total=1.615, reg=5.969, containing_obj=4.215, no_obj=1.563, cls=1.173
#
#
# Starting epoch 29 / 50
# Learning Rate for this epoch: 0.001
# Epoch [29/50], Iter [50/627], Loss: total=1.557, reg=5.678, containing_obj=4.219, no_obj=1.603, cls=0.959
# Epoch [29/50], Iter [100/627], Loss: total=1.529, reg=5.518, containing_obj=4.185, no_obj=1.551, cls=0.976
# Epoch [29/50], Iter [150/627], Loss: total=1.520, reg=5.542, containing_obj=4.135, no_obj=1.569, cls=0.914
# Epoch [29/50], Iter [200/627], Loss: total=1.536, reg=5.577, containing_obj=4.165, no_obj=1.565, cls=0.978
# Epoch [29/50], Iter [250/627], Loss: total=1.563, reg=5.744, containing_obj=4.169, no_obj=1.564, cls=1.029
# Epoch [29/50], Iter [300/627], Loss: total=1.595, reg=5.918, containing_obj=4.224, no_obj=1.582, cls=1.037
# Epoch [29/50], Iter [350/627], Loss: total=1.588, reg=5.870, containing_obj=4.197, no_obj=1.579, cls=1.057
# Epoch [29/50], Iter [400/627], Loss: total=1.596, reg=5.859, containing_obj=4.223, no_obj=1.575, cls=1.108
# Epoch [29/50], Iter [450/627], Loss: total=1.606, reg=5.905, containing_obj=4.244, no_obj=1.577, cls=1.119
# Epoch [29/50], Iter [500/627], Loss: total=1.618, reg=5.937, containing_obj=4.277, no_obj=1.594, cls=1.139
# Epoch [29/50], Iter [550/627], Loss: total=1.630, reg=5.985, containing_obj=4.319, no_obj=1.590, cls=1.146
# Epoch [29/50], Iter [600/627], Loss: total=1.634, reg=6.011, containing_obj=4.323, no_obj=1.588, cls=1.150
#
#
# Starting epoch 30 / 50
# Learning Rate for this epoch: 0.001
# Epoch [30/50], Iter [50/627], Loss: total=1.527, reg=5.464, containing_obj=4.105, no_obj=1.472, cls=1.170
# Epoch [30/50], Iter [100/627], Loss: total=1.583, reg=5.627, containing_obj=4.312, no_obj=1.484, cls=1.243
# Epoch [30/50], Iter [150/627], Loss: total=1.563, reg=5.606, containing_obj=4.275, no_obj=1.514, cls=1.106
# Epoch [30/50], Iter [200/627], Loss: total=1.586, reg=5.668, containing_obj=4.336, no_obj=1.573, cls=1.115
# Epoch [30/50], Iter [250/627], Loss: total=1.600, reg=5.779, containing_obj=4.310, no_obj=1.565, cls=1.145
# Epoch [30/50], Iter [300/627], Loss: total=1.622, reg=5.924, containing_obj=4.295, no_obj=1.581, cls=1.179
# Epoch [30/50], Iter [350/627], Loss: total=1.616, reg=5.889, containing_obj=4.269, no_obj=1.575, cls=1.192
# Epoch [30/50], Iter [400/627], Loss: total=1.631, reg=5.971, containing_obj=4.290, no_obj=1.577, cls=1.208
# Epoch [30/50], Iter [450/627], Loss: total=1.642, reg=6.018, containing_obj=4.307, no_obj=1.584, cls=1.227
# Epoch [30/50], Iter [500/627], Loss: total=1.653, reg=6.070, containing_obj=4.303, no_obj=1.594, cls=1.261
# Epoch [30/50], Iter [550/627], Loss: total=1.643, reg=6.003, containing_obj=4.284, no_obj=1.588, cls=1.272
# Epoch [30/50], Iter [600/627], Loss: total=1.647, reg=6.015, containing_obj=4.278, no_obj=1.588, cls=1.291
# ---Evaluate model on test samples---
# ...
# Epoch [40/50], Iter [100/627], Loss: total=1.240, reg=4.472, containing_obj=3.332, no_obj=1.453, cls=0.661
# Epoch [40/50], Iter [150/627], Loss: total=1.227, reg=4.380, containing_obj=3.313, no_obj=1.489, cls=0.631
# Epoch [40/50], Iter [200/627], Loss: total=1.230, reg=4.347, containing_obj=3.371, no_obj=1.499, cls=0.624
# Epoch [40/50], Iter [250/627], Loss: total=1.232, reg=4.348, containing_obj=3.395, no_obj=1.486, cls=0.627
# Epoch [40/50], Iter [300/627], Loss: total=1.251, reg=4.416, containing_obj=3.444, no_obj=1.484, cls=0.664
# Epoch [40/50], Iter [350/627], Loss: total=1.258, reg=4.434, containing_obj=3.480, no_obj=1.485, cls=0.661
# Epoch [40/50], Iter [400/627], Loss: total=1.267, reg=4.475, containing_obj=3.503, no_obj=1.494, cls=0.663
# Epoch [40/50], Iter [450/627], Loss: total=1.270, reg=4.494, containing_obj=3.504, no_obj=1.492, cls=0.668
# Epoch [40/50], Iter [500/627], Loss: total=1.277, reg=4.542, containing_obj=3.516, no_obj=1.488, cls=0.668
# Epoch [40/50], Iter [550/627], Loss: total=1.282, reg=4.558, containing_obj=3.549, no_obj=1.493, cls=0.659
# Epoch [40/50], Iter [600/627], Loss: total=1.280, reg=4.547, containing_obj=3.549, no_obj=1.495, cls=0.650
# ---Evaluate model on test samples---
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [02:10<00:00, 37.96it/s]
# ---class aeroplane ap 0.5249557526392863---
# ---class bicycle ap 0.6778436386213776---
# ---class bird ap 0.534027178737094---
# ---class boat ap 0.3171048708357338---
# ---class bottle ap 0.2526372960508123---
# ---class bus ap 0.6842896918705796---
# ---class car ap 0.7066316322416958---
# ---class cat ap 0.7239969363250713---
# ---class chair ap 0.32349541521058606---
# ---class cow ap 0.6122083079828663---
# ---class diningtable ap 0.39454537391478833---
# ---class dog ap 0.6493336257618362---
# ---class horse ap 0.7206648401896363---
# ---class motorbike ap 0.6433807107105993---
# ---class person ap 0.5885898876675191---
# ---class pottedplant ap 0.23098391749838004---
# ---class sheep ap 0.5400028503358179---
# ---class sofa ap 0.5175547215298073---
# ---class train ap 0.6846751536133178---
# ---class tvmonitor ap 0.5672610788944321---
# ---map 0.5447091440315619---
# 39 [0.5249557526392863, 0.6778436386213776, 0.534027178737094, 0.3171048708357338, 0.2526372960508123, 0.6842896918705796, 0.7066316322416958, 0.7239969363250713, 0.32349541521058606, 0.6122083079828663, 0.39454537391478833, 0.6493336257618362, 0.7206648401896363, 0.6433807107105993, 0.5885898876675191, 0.23098391749838004, 0.5400028503358179, 0.5175547215298073, 0.6846751536133178, 0.5672610788944321]
#
#
# Starting epoch 41 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [41/50], Iter [50/627], Loss: total=1.198, reg=4.197, containing_obj=3.399, no_obj=1.500, cls=0.485
# Epoch [41/50], Iter [100/627], Loss: total=1.231, reg=4.326, containing_obj=3.515, no_obj=1.466, cls=0.538
# Epoch [41/50], Iter [150/627], Loss: total=1.268, reg=4.507, containing_obj=3.615, no_obj=1.464, cls=0.561
# Epoch [41/50], Iter [200/627], Loss: total=1.270, reg=4.524, containing_obj=3.590, no_obj=1.488, cls=0.557
# Epoch [41/50], Iter [250/627], Loss: total=1.263, reg=4.508, containing_obj=3.558, no_obj=1.465, cls=0.573
# Epoch [41/50], Iter [300/627], Loss: total=1.254, reg=4.480, containing_obj=3.521, no_obj=1.470, cls=0.560
# Epoch [41/50], Iter [350/627], Loss: total=1.272, reg=4.537, containing_obj=3.548, no_obj=1.490, cls=0.601
# Epoch [41/50], Iter [400/627], Loss: total=1.266, reg=4.498, containing_obj=3.543, no_obj=1.494, cls=0.593
# Epoch [41/50], Iter [450/627], Loss: total=1.262, reg=4.483, containing_obj=3.528, no_obj=1.498, cls=0.590
# Epoch [41/50], Iter [500/627], Loss: total=1.248, reg=4.428, containing_obj=3.488, no_obj=1.484, cls=0.589
# Epoch [41/50], Iter [550/627], Loss: total=1.259, reg=4.464, containing_obj=3.534, no_obj=1.492, cls=0.585
# Epoch [41/50], Iter [600/627], Loss: total=1.267, reg=4.498, containing_obj=3.540, no_obj=1.493, cls=0.604
#
#
# Starting epoch 42 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [42/50], Iter [50/627], Loss: total=1.168, reg=3.805, containing_obj=3.535, no_obj=1.496, cls=0.506
# Epoch [42/50], Iter [100/627], Loss: total=1.246, reg=4.190, containing_obj=3.707, no_obj=1.464, cls=0.604
# Epoch [42/50], Iter [150/627], Loss: total=1.260, reg=4.259, containing_obj=3.763, no_obj=1.469, cls=0.589
# Epoch [42/50], Iter [200/627], Loss: total=1.227, reg=4.160, containing_obj=3.609, no_obj=1.462, cls=0.585
# Epoch [42/50], Iter [250/627], Loss: total=1.221, reg=4.180, containing_obj=3.540, no_obj=1.473, cls=0.577
# Epoch [42/50], Iter [300/627], Loss: total=1.233, reg=4.255, containing_obj=3.547, no_obj=1.481, cls=0.578
# Epoch [42/50], Iter [350/627], Loss: total=1.237, reg=4.299, containing_obj=3.538, no_obj=1.473, cls=0.588
# Epoch [42/50], Iter [400/627], Loss: total=1.230, reg=4.278, containing_obj=3.504, no_obj=1.462, cls=0.594
# Epoch [42/50], Iter [450/627], Loss: total=1.239, reg=4.311, containing_obj=3.543, no_obj=1.466, cls=0.595
# Epoch [42/50], Iter [500/627], Loss: total=1.247, reg=4.359, containing_obj=3.548, no_obj=1.477, cls=0.595
# Epoch [42/50], Iter [550/627], Loss: total=1.241, reg=4.344, containing_obj=3.516, no_obj=1.471, cls=0.599
# Epoch [42/50], Iter [600/627], Loss: total=1.243, reg=4.358, containing_obj=3.529, no_obj=1.463, cls=0.592
# Updating best test loss: 2.60758
#
#
# Starting epoch 43 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [43/50], Iter [50/627], Loss: total=1.289, reg=4.445, containing_obj=3.528, no_obj=1.619, cls=0.723
# Epoch [43/50], Iter [100/627], Loss: total=1.303, reg=4.596, containing_obj=3.589, no_obj=1.553, cls=0.688
# Epoch [43/50], Iter [150/627], Loss: total=1.285, reg=4.647, containing_obj=3.506, no_obj=1.492, cls=0.636
# Epoch [43/50], Iter [200/627], Loss: total=1.278, reg=4.561, containing_obj=3.510, no_obj=1.477, cls=0.674
# Epoch [43/50], Iter [250/627], Loss: total=1.270, reg=4.519, containing_obj=3.518, no_obj=1.471, cls=0.650
# Epoch [43/50], Iter [300/627], Loss: total=1.263, reg=4.492, containing_obj=3.484, no_obj=1.471, cls=0.653
# Epoch [43/50], Iter [350/627], Loss: total=1.256, reg=4.461, containing_obj=3.467, no_obj=1.478, cls=0.646
# Epoch [43/50], Iter [400/627], Loss: total=1.257, reg=4.460, containing_obj=3.479, no_obj=1.491, cls=0.625
# Epoch [43/50], Iter [450/627], Loss: total=1.262, reg=4.472, containing_obj=3.499, no_obj=1.479, cls=0.644
# Epoch [43/50], Iter [500/627], Loss: total=1.258, reg=4.454, containing_obj=3.502, no_obj=1.482, cls=0.629
# Epoch [43/50], Iter [550/627], Loss: total=1.257, reg=4.454, containing_obj=3.485, no_obj=1.490, cls=0.623
# Epoch [43/50], Iter [600/627], Loss: total=1.254, reg=4.461, containing_obj=3.467, no_obj=1.488, cls=0.619
#
#
# Starting epoch 44 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [44/50], Iter [50/627], Loss: total=1.378, reg=5.154, containing_obj=3.807, no_obj=1.454, cls=0.605
# Epoch [44/50], Iter [100/627], Loss: total=1.246, reg=4.536, containing_obj=3.382, no_obj=1.465, cls=0.583
# Epoch [44/50], Iter [150/627], Loss: total=1.224, reg=4.384, containing_obj=3.359, no_obj=1.509, cls=0.539
# Epoch [44/50], Iter [200/627], Loss: total=1.242, reg=4.448, containing_obj=3.399, no_obj=1.506, cls=0.580
# Epoch [44/50], Iter [250/627], Loss: total=1.257, reg=4.478, containing_obj=3.465, no_obj=1.505, cls=0.606
# Epoch [44/50], Iter [300/627], Loss: total=1.271, reg=4.536, containing_obj=3.497, no_obj=1.528, cls=0.608
# Epoch [44/50], Iter [350/627], Loss: total=1.263, reg=4.499, containing_obj=3.473, no_obj=1.523, cls=0.605
# Epoch [44/50], Iter [400/627], Loss: total=1.251, reg=4.443, containing_obj=3.434, no_obj=1.512, cls=0.620
# Epoch [44/50], Iter [450/627], Loss: total=1.251, reg=4.437, containing_obj=3.449, no_obj=1.516, cls=0.604
# Epoch [44/50], Iter [500/627], Loss: total=1.256, reg=4.461, containing_obj=3.471, no_obj=1.509, cls=0.606
# Epoch [44/50], Iter [550/627], Loss: total=1.269, reg=4.520, containing_obj=3.498, no_obj=1.510, cls=0.628
# Epoch [44/50], Iter [600/627], Loss: total=1.269, reg=4.510, containing_obj=3.503, no_obj=1.514, cls=0.629
#
#
# Starting epoch 45 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [45/50], Iter [50/627], Loss: total=1.257, reg=4.375, containing_obj=3.594, no_obj=1.447, cls=0.639
# Epoch [45/50], Iter [100/627], Loss: total=1.270, reg=4.475, containing_obj=3.590, no_obj=1.467, cls=0.631
# Epoch [45/50], Iter [150/627], Loss: total=1.268, reg=4.525, containing_obj=3.556, no_obj=1.454, cls=0.607
# Epoch [45/50], Iter [200/627], Loss: total=1.282, reg=4.562, containing_obj=3.549, no_obj=1.471, cls=0.672
# Epoch [45/50], Iter [250/627], Loss: total=1.272, reg=4.544, containing_obj=3.530, no_obj=1.464, cls=0.639
# Epoch [45/50], Iter [300/627], Loss: total=1.260, reg=4.469, containing_obj=3.519, no_obj=1.482, cls=0.609
# Epoch [45/50], Iter [350/627], Loss: total=1.258, reg=4.469, containing_obj=3.533, no_obj=1.455, cls=0.606
# Epoch [45/50], Iter [400/627], Loss: total=1.252, reg=4.431, containing_obj=3.511, no_obj=1.460, cls=0.615
# Epoch [45/50], Iter [450/627], Loss: total=1.243, reg=4.400, containing_obj=3.474, no_obj=1.462, cls=0.607
# Epoch [45/50], Iter [500/627], Loss: total=1.247, reg=4.427, containing_obj=3.473, no_obj=1.472, cls=0.607
# Epoch [45/50], Iter [550/627], Loss: total=1.249, reg=4.441, containing_obj=3.475, no_obj=1.476, cls=0.602
# Epoch [45/50], Iter [600/627], Loss: total=1.245, reg=4.415, containing_obj=3.471, no_obj=1.477, cls=0.600
# ---Evaluate model on test samples---
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [02:09<00:00, 38.32it/s]
# ---class aeroplane ap 0.5388213772560031---
# ---class bicycle ap 0.6691236151438158---
# ---class bird ap 0.5446607588917977---
# ---class boat ap 0.3357972899213061---
# ---class bottle ap 0.2525183473783543---
# ---class bus ap 0.6809513593176464---
# ---class car ap 0.7050482783972051---
# ---class cat ap 0.7077935758755526---
# ---class chair ap 0.31744141867897674---
# ---class cow ap 0.5818529410722033---
# ---class diningtable ap 0.41313161839590096---
# ---class dog ap 0.6516629396451994---
# ---class horse ap 0.7381451728177839---
# ---class motorbike ap 0.6452476105227343---
# ---class person ap 0.5948072063582956---
# ---class pottedplant ap 0.20928061289917665---
# ---class sheep ap 0.521858850271331---
# ---class sofa ap 0.5075140187693713---
# ---class train ap 0.6990768229651548---
# ---class tvmonitor ap 0.5731960343667202---
# ---map 0.5443964924472264---
# 44 [0.5388213772560031, 0.6691236151438158, 0.5446607588917977, 0.3357972899213061, 0.2525183473783543, 0.6809513593176464, 0.7050482783972051, 0.7077935758755526, 0.31744141867897674, 0.5818529410722033, 0.41313161839590096, 0.6516629396451994, 0.7381451728177839, 0.6452476105227343, 0.5948072063582956, 0.20928061289917665, 0.521858850271331, 0.5075140187693713, 0.6990768229651548, 0.5731960343667202]
# Updating best test loss: 2.60681
#
#
# Starting epoch 46 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [46/50], Iter [50/627], Loss: total=1.264, reg=4.619, containing_obj=3.383, no_obj=1.493, cls=0.621
# Epoch [46/50], Iter [100/627], Loss: total=1.231, reg=4.384, containing_obj=3.372, no_obj=1.479, cls=0.610
# Epoch [46/50], Iter [150/627], Loss: total=1.230, reg=4.322, containing_obj=3.374, no_obj=1.508, cls=0.635
# Epoch [46/50], Iter [200/627], Loss: total=1.210, reg=4.214, containing_obj=3.359, no_obj=1.504, cls=0.601
# Epoch [46/50], Iter [250/627], Loss: total=1.232, reg=4.341, containing_obj=3.376, no_obj=1.506, cls=0.635
# Epoch [46/50], Iter [300/627], Loss: total=1.239, reg=4.394, containing_obj=3.390, no_obj=1.496, cls=0.631
# Epoch [46/50], Iter [350/627], Loss: total=1.236, reg=4.406, containing_obj=3.367, no_obj=1.501, cls=0.616
# Epoch [46/50], Iter [400/627], Loss: total=1.228, reg=4.358, containing_obj=3.360, no_obj=1.507, cls=0.597
# Epoch [46/50], Iter [450/627], Loss: total=1.232, reg=4.387, containing_obj=3.377, no_obj=1.511, cls=0.581
# Epoch [46/50], Iter [500/627], Loss: total=1.231, reg=4.371, containing_obj=3.384, no_obj=1.517, cls=0.577
# Epoch [46/50], Iter [550/627], Loss: total=1.244, reg=4.431, containing_obj=3.419, no_obj=1.519, cls=0.584
# Epoch [46/50], Iter [600/627], Loss: total=1.246, reg=4.426, containing_obj=3.427, no_obj=1.522, cls=0.594
#
#
# Starting epoch 47 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [47/50], Iter [50/627], Loss: total=1.218, reg=4.395, containing_obj=3.333, no_obj=1.468, cls=0.547
# Epoch [47/50], Iter [100/627], Loss: total=1.210, reg=4.315, containing_obj=3.288, no_obj=1.446, cls=0.630
# Epoch [47/50], Iter [150/627], Loss: total=1.244, reg=4.497, containing_obj=3.420, no_obj=1.401, cls=0.634
# Epoch [47/50], Iter [200/627], Loss: total=1.268, reg=4.591, containing_obj=3.465, no_obj=1.446, cls=0.640
# Epoch [47/50], Iter [250/627], Loss: total=1.266, reg=4.578, containing_obj=3.464, no_obj=1.462, cls=0.627
# Epoch [47/50], Iter [300/627], Loss: total=1.262, reg=4.523, containing_obj=3.459, no_obj=1.481, cls=0.634
# Epoch [47/50], Iter [350/627], Loss: total=1.249, reg=4.476, containing_obj=3.427, no_obj=1.477, cls=0.609
# Epoch [47/50], Iter [400/627], Loss: total=1.258, reg=4.515, containing_obj=3.451, no_obj=1.484, cls=0.616
# Epoch [47/50], Iter [450/627], Loss: total=1.258, reg=4.502, containing_obj=3.451, no_obj=1.499, cls=0.613
# Epoch [47/50], Iter [500/627], Loss: total=1.260, reg=4.531, containing_obj=3.444, no_obj=1.491, cls=0.613
# Epoch [47/50], Iter [550/627], Loss: total=1.271, reg=4.582, containing_obj=3.475, no_obj=1.494, cls=0.616
# Epoch [47/50], Iter [600/627], Loss: total=1.266, reg=4.565, containing_obj=3.460, no_obj=1.488, cls=0.612
#
#
# Starting epoch 48 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [48/50], Iter [50/627], Loss: total=1.229, reg=4.430, containing_obj=3.422, no_obj=1.452, cls=0.525
# Epoch [48/50], Iter [100/627], Loss: total=1.244, reg=4.423, containing_obj=3.440, no_obj=1.463, cls=0.623
# Epoch [48/50], Iter [150/627], Loss: total=1.244, reg=4.367, containing_obj=3.497, no_obj=1.472, cls=0.619
# Epoch [48/50], Iter [200/627], Loss: total=1.239, reg=4.386, containing_obj=3.430, no_obj=1.472, cls=0.628
# Epoch [48/50], Iter [250/627], Loss: total=1.228, reg=4.344, containing_obj=3.397, no_obj=1.451, cls=0.634
# Epoch [48/50], Iter [300/627], Loss: total=1.223, reg=4.313, containing_obj=3.395, no_obj=1.470, cls=0.607
# Epoch [48/50], Iter [350/627], Loss: total=1.224, reg=4.314, containing_obj=3.395, no_obj=1.483, cls=0.598
# Epoch [48/50], Iter [400/627], Loss: total=1.236, reg=4.351, containing_obj=3.446, no_obj=1.487, cls=0.606
# Epoch [48/50], Iter [450/627], Loss: total=1.241, reg=4.359, containing_obj=3.490, no_obj=1.477, cls=0.605
# Epoch [48/50], Iter [500/627], Loss: total=1.232, reg=4.321, containing_obj=3.470, no_obj=1.466, cls=0.597
# Epoch [48/50], Iter [550/627], Loss: total=1.237, reg=4.352, containing_obj=3.479, no_obj=1.466, cls=0.602
# Epoch [48/50], Iter [600/627], Loss: total=1.246, reg=4.380, containing_obj=3.498, no_obj=1.473, cls=0.615
#
#
# Starting epoch 49 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [49/50], Iter [50/627], Loss: total=1.180, reg=4.193, containing_obj=3.224, no_obj=1.499, cls=0.527
# Epoch [49/50], Iter [100/627], Loss: total=1.195, reg=4.131, containing_obj=3.326, no_obj=1.548, cls=0.554
# Epoch [49/50], Iter [150/627], Loss: total=1.179, reg=4.077, containing_obj=3.317, no_obj=1.517, cls=0.523
# Epoch [49/50], Iter [200/627], Loss: total=1.203, reg=4.200, containing_obj=3.341, no_obj=1.524, cls=0.555
# Epoch [49/50], Iter [250/627], Loss: total=1.217, reg=4.275, containing_obj=3.395, no_obj=1.509, cls=0.555
# Epoch [49/50], Iter [300/627], Loss: total=1.233, reg=4.404, containing_obj=3.394, no_obj=1.513, cls=0.553
# Epoch [49/50], Iter [350/627], Loss: total=1.238, reg=4.404, containing_obj=3.410, no_obj=1.515, cls=0.575
# Epoch [49/50], Iter [400/627], Loss: total=1.245, reg=4.433, containing_obj=3.427, no_obj=1.506, cls=0.595

# %% [markdown]
# # View example predictions

# %%
net.eval()

# select random image from test set
image_name = random.choice(test_dataset.fnames)
image = cv2.imread(os.path.join(file_root_test, image_name))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

print('predicting...')
result = predict_image(net, image_name, root_img_directory=file_root_test)
for left_up, right_bottom, class_name, _, prob in result:
    color = COLORS[VOC_CLASSES.index(class_name)]
    cv2.rectangle(image, left_up, right_bottom, color, 2)
    label = class_name + str(round(prob, 2))
    text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
    p1 = (left_up[0], left_up[1] - text_size[1])
    cv2.rectangle(image, (p1[0] - 2 // 2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]),
                  color, -1)
    cv2.putText(image, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 255), 1, 8)

plt.figure(figsize = (15,15))
plt.imshow(image)
# Out:
# predicting...

# %% [markdown]
# ## Evaluate on Test
#
# To evaluate detection results we use mAP (mean of average precision over each class)

# %%
test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# ---Evaluate model on test samples---
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [02:06<00:00, 39.25it/s]
# ---class aeroplane ap 0.5388213772560031---
# ---class bicycle ap 0.6691236151438158---
# ---class bird ap 0.5446607588917977---
# ---class boat ap 0.3357972899213061---
# ---class bottle ap 0.2525183473783543---
# ---class bus ap 0.6809513593176464---
# ---class car ap 0.7050482783972051---
# ---class cat ap 0.7077935758755526---
# ---class chair ap 0.31744141867897674---
# ---class cow ap 0.5818529410722033---
# ---class diningtable ap 0.41313161839590096---
# ---class dog ap 0.6516629396451994---
# ---class horse ap 0.7381451728177839---
# ---class motorbike ap 0.6452476105227343---
# ---class person ap 0.5948072063582956---
# ---class pottedplant ap 0.20928061289917665---
# ---class sheep ap 0.521858850271331---
# ---class sofa ap 0.5075140187693713---
# ---class train ap 0.6990768229651548---
# ---class tvmonitor ap 0.5731960343667202---
# ---map 0.5443964924472264---

# %% [markdown]
# ### Cell added to get intermediate mAP values for students

# %%
network_paths = ['./checkpoints/detector_epoch_%d.pth' % epoch for epoch in [5, 10, 20, 30, 40]]+['./checkpoints/detector.pth']
for load_network_path in network_paths:
    print('Loading saved network from {}'.format(load_network_path))
    net_loaded =  resnet50().to(device)
    net_loaded.load_state_dict(torch.load(load_network_path))
    evaluate(net_loaded, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# Loading saved network from ./checkpoints/detector_epoch_5.pth
# ---Evaluate model on test samples---
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [02:06<00:00, 39.01it/s]
# ---class aeroplane ap 0.48027260319872345---
# ---class bicycle ap 0.6601371158275703---
# ---class bird ap 0.38624070621031437---
# ---class boat ap 0.32051399514354995---
# ---class bottle ap 0.1784986696410527---
# ---class bus ap 0.623276632924607---
# ---class car ap 0.6383006450413673---
# ---class cat ap 0.6879070368519352---
# ---class chair ap 0.2723186918873418---
# ---class cow ap 0.4655593153757174---
# ---class diningtable ap 0.32510678853807484---
# ---class dog ap 0.6011875080758059---
# ---class horse ap 0.6013828339341694---
# ---class motorbike ap 0.5283609191154686---
# ---class person ap 0.5605328004143579---
# ---class pottedplant ap 0.15435281692470287---
# ---class sheep ap 0.4857010008828496---
# ---class sofa ap 0.4726504403162114---
# ---class train ap 0.6001783124861151---
# ---class tvmonitor ap 0.5278058437184066---
# ---map 0.4785142338254171---
# Loading saved network from ./checkpoints/detector_epoch_10.pth
# ---Evaluate model on test samples---
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [02:06<00:00, 39.06it/s]
# ---class aeroplane ap 0.45306807107493163---
# ---class bicycle ap 0.6031199148436923---
# ---class bird ap 0.4366665089787085---
# ---class boat ap 0.2562862904227968---
# ---class bottle ap 0.22573602510302102---
# ---class bus ap 0.5968211915982558---
# ---class car ap 0.6356348248347746---
# ---class cat ap 0.6686293030451655---
# ---class chair ap 0.2933344639406329---
# ---class cow ap 0.540007646631129---
# ---class diningtable ap 0.345083055309979---
# ---class dog ap 0.465720536584587---
# ---class horse ap 0.693405688502286---
# ---class motorbike ap 0.5216900211416011---
# ---class person ap 0.5649454499989359---
# ---class pottedplant ap 0.1849600924079474---
# ---class sheep ap 0.46362846237011013---
# ---class sofa ap 0.435696443410753---
# ---class train ap 0.597070359758239---
# ---class tvmonitor ap 0.4641627843184898---
# ---map 0.4722833567138018---
# Loading saved network from ./checkpoints/detector_epoch_20.pth
# ---Evaluate model on test samples---
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [02:05<00:00, 39.35it/s]
# ---class aeroplane ap 0.4374534730642129---
# ---class bicycle ap 0.6189195305801062---
# ---class bird ap 0.4789663391724595---
# ---class boat ap 0.28408233546400896---
# ---class bottle ap 0.20504861067814922---
# ---class bus ap 0.6321854218996397---
# ---class car ap 0.6743551704986563---
# ---class cat ap 0.6343822395569088---
# ---class chair ap 0.31295215184230935---
# ---class cow ap 0.4845876509147483---
# ---class diningtable ap 0.40129578601130084---
# ---class dog ap 0.6281053399642207---
# ---class horse ap 0.6164116543932285---
# ---class motorbike ap 0.537851506688281---
# ---class person ap 0.5753829567934738---
# ---class pottedplant ap 0.17174634127554236---
# ---class sheep ap 0.42279653464020195---
# ---class sofa ap 0.4490801525926465---
# ---class train ap 0.6443435664015074---
# ---class tvmonitor ap 0.461130999900087---
# ---map 0.4835538881165845---
# Loading saved network from ./checkpoints/detector_epoch_30.pth
# ---Evaluate model on test samples---
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [02:06<00:00, 39.16it/s]
# ---class aeroplane ap 0.4890766418376312---
# ---class bicycle ap 0.5456809343354239---
# ---class bird ap 0.5077169360960176---
# ---class boat ap 0.25021539378324337---
# ---class bottle ap 0.23587174118701681---
# ---class bus ap 0.6089431152874701---
# ---class car ap 0.6821499702559601---
# ---class cat ap 0.6372485216909589---
# ---class chair ap 0.325654922961693---
# ---class cow ap 0.5088600927609255---
# ---class diningtable ap 0.42944765990353156---
# ---class dog ap 0.611985057977032---
# ---class horse ap 0.6404672448941292---
# ---class motorbike ap 0.5840212056930085---
# ---class person ap 0.5743054102126032---
# ---class pottedplant ap 0.1816146328007903---
# ---class sheep ap 0.48995281705438054---
# ---class sofa ap 0.45785973695462---
# ---class train ap 0.599270562674552---
# ---class tvmonitor ap 0.49448355114453896---
# ---map 0.4927413074752763---
# Loading saved network from ./checkpoints/detector_epoch_40.pth
# ---Evaluate model on test samples---
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [02:06<00:00, 39.20it/s]
# ---class aeroplane ap 0.5249557526392863---
# ---class bicycle ap 0.6778436386213776---
# ---class bird ap 0.534027178737094---
# ---class boat ap 0.3171048708357338---
# ---class bottle ap 0.2526372960508123---
# ---class bus ap 0.6842896918705796---
# ---class car ap 0.7066316322416958---
# ---class cat ap 0.7239969363250713---
# ---class chair ap 0.32349541521058606---
# ---class cow ap 0.6122083079828663---
# ---class diningtable ap 0.39454537391478833---
# ---class dog ap 0.6493336257618362---
# ---class horse ap 0.7206648401896363---
# ---class motorbike ap 0.6433807107105993---
# ---class person ap 0.5885898876675191---
# ---class pottedplant ap 0.23098391749838004---
# ---class sheep ap 0.5400028503358179---
# ---class sofa ap 0.5175547215298073---
# ---class train ap 0.6846751536133178---
# ---class tvmonitor ap 0.5672610788944321---
# ---map 0.5447091440315619---
# Loading saved network from ./checkpoints/detector.pth
# ---Evaluate model on test samples---
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [02:06<00:00, 39.18it/s]
# ---class aeroplane ap 0.52912728802196---
# ---class bicycle ap 0.6718376055200832---
# ---class bird ap 0.5461591776018675---
# ---class boat ap 0.3285663483405106---
# ---class bottle ap 0.24949215207050862---
# ---class bus ap 0.6905241710336256---
# ---class car ap 0.7089279713586965---
# ---class cat ap 0.7223267039604646---
# ---class chair ap 0.331268629272347---
# ---class cow ap 0.6105901592829525---
# ---class diningtable ap 0.4218881034490982---
# ---class dog ap 0.6648993018831915---
# ---class horse ap 0.7302232171728874---
# ---class motorbike ap 0.6403875203916032---
# ---class person ap 0.5965550891006175---
# ---class pottedplant ap 0.22263546115801247---
# ---class sheep ap 0.524089596503744---
# ---class sofa ap 0.4895127878111042---
# ---class train ap 0.672020099339081---
# ---class tvmonitor ap 0.5718222856372372---
# ---map 0.5461426834454797---

# %%
output_submission_csv('my_new_solution.csv', test_aps)
